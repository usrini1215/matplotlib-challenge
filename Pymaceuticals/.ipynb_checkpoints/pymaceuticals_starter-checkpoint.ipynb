# %% [markdown]
# ## Observations and Insights

# %%
#Look across all previously generated figures and tables 
#and write at least three observations or inferences that can be made from the data. 
#Include these observations at the top of notebook.

#These are my observations:

#1 I found that Ramicaine had a 'slightly' better outcome than Capumolin based on 
#  the median and shape from the box plot, denoted below.  And the second best was 
#  Capomulin which was the choice of drug for our organization

#2  Capomulin had a distinct reduction in tumor volume over time
#   From a volume of 45 to 31 over the course of time points, alose denoted below in a chart

#3  There is a linear relationship betn the weight and tumor volume in that it was
#   observed that the higher the weight bigger the tumor.

#4 The gender split and the number of mice tested per drug 
#  seemed like a good choice of testing and this is denote in the 
#  pie chart below (!24 versus 125)

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import linregress


# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
merged_df = pd.merge(mouse_metadata,study_results, on="Mouse ID")

# Display the data table for preview
merged_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice.
mice_total_all = len(merged_df["Mouse ID"])

print(f"Total number of mice (includes duplicates) : {mice_total_all}")

mice_total_unique = len(merged_df["Mouse ID"].unique())

print(f"Total number of mice (without duplicates) : {mice_total_unique}")
# Out:
# Total number of mice (includes duplicates) : 1893
# Total number of mice (without duplicates) : 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 

#this returns only 5
#duplicate_mice_df = merged_df[merged_df[['Mouse ID','Timepoint']].duplicated()]

#gave 12 records
#ids = merged_df["Mouse ID"]
#duplicate_mice_df = merged_df[ids.isin(ids[ids.duplicated()])].sort_values("Mouse ID")

#gave 5 records
#duplicate_mice_df = merged_df[merged_df.duplicated(subset=['Mouse ID','Timepoint'], keep='first')]

duplicate_mice_ids = merged_df.loc[merged_df.duplicated(subset=['Mouse ID','Timepoint']),'Mouse ID'].unique()

duplicate_mice_ids
# Out:
# array(['g989'], dtype=object)

# %%
# Optional: Get all the data for the duplicate mouse ID. 

#all_dupe_data_df = merged_df.loc[merged_df.duplicated(subset =["Mouse ID","Timepoint"],keep=False)==True]

all_dupe_data_df = merged_df.loc[merged_df["Mouse ID"].isin(duplicate_mice_ids)]

print(len(all_dupe_data_df))
all_dupe_data_df
# Out:
# 13
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 908     g989     Propriva  Female          21          26          0
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
# 918     g989     Propriva  Female          21          26         25
# 919     g989     Propriva  Female          21          26         30
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
#clean_df = merged_df.drop_duplicates(subset=['Mouse ID','Timepoint'],keep = "last")

clean_df = merged_df.loc[merged_df["Mouse ID"].isin(duplicate_mice_ids) == False]

clean_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice in the clean DataFrame.
mice_total_clean = len(clean_df["Mouse ID"].unique())

print(f"Total number of mice in clean dataframe : {mice_total_clean}")
# Out:
# Total number of mice in clean dataframe : 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# This method is the most straighforward, creating multiple series and putting them all together at the end.

mean_tumor = clean_df.groupby("Drug Regimen")["Tumor Volume (mm3)"].mean()
median_tumor = clean_df.groupby("Drug Regimen")["Tumor Volume (mm3)"].median()
std_tumor = clean_df.groupby("Drug Regimen")["Tumor Volume (mm3)"].std()
var_tumor = clean_df.groupby("Drug Regimen")["Tumor Volume (mm3)"].var()
sem_tumor = clean_df.groupby("Drug Regimen")["Tumor Volume (mm3)"].sem()

tumor_drug_summary_df = pd.DataFrame({"Mean" : mean_tumor,
                                     "Median" : median_tumor,
                                     "Variance" : var_tumor,
                                     "Standard Deviation" : std_tumor,
                                     "SEM" : sem_tumor})

#print(mean_tumor,median_tumor,mode_tumor,std_tumor,var_tumor,sem_tumor)
tumor_drug_summary_df
# Out:
#                    Mean     Median   Variance  Standard Deviation       SEM
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764            4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177            6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684            6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577            8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479            8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083            7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013            6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704            4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562            7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355            6.966589  0.516398

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

clean_df.groupby("Drug Regimen")['Tumor Volume (mm3)'].agg(['mean','median','std','var','sem'])
# Out:
#                    mean     median       std        var       sem
# Drug Regimen
# Capomulin     40.675741  41.557809  4.994774  24.947764  0.329346
# Ceftamin      52.591172  51.776157  6.268188  39.290177  0.469821
# Infubinol     52.884795  51.820584  6.567243  43.128684  0.492236
# Ketapril      55.235638  53.698743  8.279709  68.553577  0.603860
# Naftisol      54.331565  52.509285  8.134708  66.173479  0.596466
# Placebo       54.033581  52.288934  7.821003  61.168083  0.581331
# Propriva      52.320930  50.446266  6.622085  43.852013  0.544332
# Ramicane      40.216745  40.673236  4.846308  23.486704  0.320955
# Stelasyn      54.233149  52.431737  7.710419  59.450562  0.573111
# Zoniferol     53.236507  51.818479  6.966589  48.533355  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pandas. 

miceCount = clean_df.groupby(['Drug Regimen'])[["Mouse ID"]].nunique()

pbar = miceCount.plot.bar(title = 'Number of Mice per Regimen (no dupes)',legend = False, color="b")
pbar.set_ylabel("Number of Mice")

miceCountOpt2 = clean_df.groupby(['Drug Regimen']).agg({'Mouse ID':'count'})
pbar2 = miceCountOpt2.plot.bar(title = 'Number of Mice trials per Regimen (with dupes)',legend = False, color="b")
pbar2.set_ylabel("Number of Mice")

#No dupes
print(miceCount)
#With dupes
print(miceCountOpt2)
# Out:
#               Mouse ID
# Drug Regimen
# Capomulin           25
# Ceftamin            25
# Infubinol           25
# Ketapril            25
# Naftisol            25
# Placebo             25
# Propriva            24
# Ramicane            25
# Stelasyn            24
# Zoniferol           25
#               Mouse ID
# Drug Regimen
# Capomulin          230
# Ceftamin           178
# Infubinol          178
# Ketapril           188
# Naftisol           186
# Placebo            181
# Propriva           148
# Ramicane           228
# Stelasyn           181
# Zoniferol          182

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pyplot.

# PLEASE NOTE : Can use these queries if needed with dupes
#mice = clean_df["Drug Regimen"].value_counts()
# x_axis = mice.keys()
# y_axis = list(mice)

mice = pd.DataFrame(clean_df.groupby(['Drug Regimen'])[["Mouse ID"]].nunique().rename(columns={'Mouse ID':'MouseCount'}))
mice = mice.reset_index()
y_axis = mice["MouseCount"].to_list()
x_axis = mice["Drug Regimen"].to_list()

plt.bar(x_axis, y_axis, color="b", align="center")
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, x_axis, rotation='vertical')

plt.title("Total number of Mice per treatment (no dupes per regimen)")
plt.xlabel("Drugs")
plt.ylabel("Number of Mice")
mice
# Out:
#   Drug Regimen  MouseCount
# 0    Capomulin          25
# 1     Ceftamin          25
# 2    Infubinol          25
# 3     Ketapril          25
# 4     Naftisol          25
# 5      Placebo          25
# 6     Propriva          24
# 7     Ramicane          25
# 8     Stelasyn          24
# 9    Zoniferol          25

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas
gender_df =  merged_df[["Mouse ID","Sex"]].drop_duplicates()
gender_df = gender_df.groupby("Sex")[["Mouse ID"]].count()

gender_df = gender_df.rename(columns={"Mouse ID": ""})

#this was to avoid Index error on the keys but not using the keys
#keys = tuple(gender_df.keys().tolist()) 

gender_pie = gender_df.plot(kind="pie",figsize=(5,5),subplots=True, startangle=120, 
                            title=("Gender variations by Mouse using pandas"),autopct="%1.1f%%", colors = ['yellow', 'green'])
gender_df
# Out:
#
# Sex
# Female  124
# Male    125

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot

gender_count = gender_df.values.tolist()
colors = ["yellow","green"]
explode = (0, 0)
genders = gender_df.index

plt.pie(gender_count, explode=explode, labels=genders, 
        colors=colors,autopct="%1.1f%%", shadow=True, startangle=120)

plt.title("Gender variations by Mouse using PyPlot")
# Out:
# /Users/samchari/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.
#   if __name__ == '__main__':
# Text(0.5, 1.0, 'Gender variations by Mouse using PyPlot')

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin


# Start by getting the last (greatest) timepoint for each mouse
last_point = clean_df.groupby("Mouse ID")[["Timepoint"]].max()
last_point

# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
tumor_df = pd.merge(last_point,clean_df,on=["Mouse ID","Timepoint"])
tumor_df
# Out:
#     Mouse ID  Timepoint Drug Regimen     Sex  Age_months  Weight (g)  \
# 0       a203         45    Infubinol  Female          20          23
# 1       a251         45    Infubinol  Female          21          25
# 2       a262         45      Placebo  Female          17          29
# 3       a275         45     Ceftamin  Female          20          28
# 4       a366         30     Stelasyn  Female          16          29
# ..       ...        ...          ...     ...         ...         ...
# 243     z435         10     Propriva  Female          12          26
# 244     z578         45     Ramicane    Male          11          16
# 245     z581         45    Infubinol  Female          24          25
# 246     z795         45     Naftisol  Female          13          29
# 247     z969         45     Naftisol    Male           9          30
#
#      Tumor Volume (mm3)  Metastatic Sites
# 0             67.973419                 2
# 1             65.525743                 1
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)
#treatments should be ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]
tr= tumor_df["Drug Regimen"].unique()
treatments = []
for i in tr:
    if i in ("Capomulin", "Ramicane", "Infubinol", "Ceftamin"):
        treatments.append(i)

        
# Create empty list to fill with tumor vol data (for plotting)
tumor_volume_list = []


# Calculate the IQR and quantitatively determine if there are any potential outliers. 
for treatment in treatments:
    treat_tumor = tumor_df.loc[tumor_df['Drug Regimen'] == treatment]
    
    quartiles = treat_tumor["Tumor Volume (mm3)"].quantile([.25,.5,.75])
    lowerq = round(quartiles[0.25],2)
    upperq = round(quartiles[0.75],2)
    iqr = round(upperq-lowerq,2)
    print("----------------------------")
    print(f"Values for drug {treatment}")
    print(f"The lower quartile of Tumor Volume for drug {treatment} is: {lowerq}")
    print(f"The upper quartile of Tumor Volume for drug {treatment} is: {upperq}")
    print(f"The interquartile range of Tumor Volume for drug {treatment} is: {iqr}")
    print(f"The the median of Tumor Volume for drug {treatment} is: {round(quartiles[0.5],2)} ")

    lower_bound = round(lowerq - (1.5*iqr),2)
    upper_bound = round(upperq + (1.5*iqr),2)
    print(f"Values below {lower_bound} could be outliers for drug {treatment}.")
    print(f"Values above {upper_bound} could be outliersfor drug {treatment}.")
    
    
# Locate the rows which contain mice on each drug and get the tumor volumes
all_drugs_rows = tumor_df.loc[tumor_df['Drug Regimen'].isin(treatments)]
#Printed below    
    
# add subset 
all_drugs_rows = all_drugs_rows[["Mouse ID","Drug Regimen","Tumor Volume (mm3)"]]   
all_drugs_rows

# Determine outliers using upper and lower bounds
# My answer for outliers and bounds was added above in the loop
# Out:
# ----------------------------
# Values for drug Infubinol
# The lower quartile of Tumor Volume for drug Infubinol is: 54.05
# The upper quartile of Tumor Volume for drug Infubinol is: 65.53
# The interquartile range of Tumor Volume for drug Infubinol is: 11.48
# The the median of Tumor Volume for drug Infubinol is: 60.17
# Values below 36.83 could be outliers for drug Infubinol.
# Values above 82.75 could be outliersfor drug Infubinol.
# ----------------------------
# Values for drug Ceftamin
# The lower quartile of Tumor Volume for drug Ceftamin is: 48.72
# The upper quartile of Tumor Volume for drug Ceftamin is: 64.3
# The interquartile range of Tumor Volume for drug Ceftamin is: 15.58
# The the median of Tumor Volume for drug Ceftamin is: 59.85
# Values below 25.35 could be outliers for drug Ceftamin.
# Values above 87.67 could be outliersfor drug Ceftamin.
# ----------------------------
# Values for drug Ramicane
# The lower quartile of Tumor Volume for drug Ramicane is: 31.56
# ...

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest


tumor_volume = all_drugs_rows.groupby('Drug Regimen')['Tumor Volume (mm3)'].apply(list)
tumor_list_df = pd.DataFrame(tumor_volume)
tumor_list_df = tumor_list_df.reindex(treatments)
print(tumor_list_df)

plt.boxplot(tumor_volume, labels=tumor_volume.index)

plt.ylim(0, 90)
plt.show()
# Out:
#                                              Tumor Volume (mm3)
# Drug Regimen
# Infubinol     [67.97341878, 65.52574285, 57.03186187, 66.083...
# Ceftamin      [62.99935619, 45.0, 56.05774909, 55.74282869, ...
# Ramicane      [38.407618299999996, 43.04754260000001, 38.810...
# Capomulin     [38.98287774, 38.93963263, 30.48598484, 37.074...

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of time point versus tumor volume for a mouse treated with Capomulin

#tumor_df.loc[tumor_df["Drug Regimen"] == "Capomulin"]
#Used above query to find a mouse treated with Capomulin
time_tumor_rec = clean_df[clean_df["Mouse ID"].isin(["u364"])]

time_tumor_data = pd.DataFrame(time_tumor_rec[["Timepoint", "Tumor Volume (mm3)"]])

line_plot_df = pd.DataFrame(time_tumor_data.set_index("Timepoint"))
print(line_plot_df)

lines = line_plot_df.plot.line()
plt.title("Line plot of Timepoint versus tumor volume for mouse u364 using Capomulin")
plt.xlabel('Timepoint')
plt.ylabel('Tumor Volume')
# Out:
#            Tumor Volume (mm3)
# Timepoint
# 0                   45.000000
# 5                   45.760886
# 10                  46.568417
# 15                  47.212200
# 20                  40.343948
# 25                  35.503616
# 30                  35.978334
# 35                  35.459490
# 40                  36.024138
# 45                  31.023923
# Text(0, 0.5, 'Tumor Volume')

# %%
# Generate a scatter plot of mouse weight versus average tumor volume for the Capomulin regimen

cap_scatter_full = clean_df[clean_df["Drug Regimen"].isin(["Capomulin"])]
cap_scatter_df = cap_scatter_full[["Mouse ID","Weight (g)", "Tumor Volume (mm3)"]]
cap_scatter_df = cap_scatter_df.reset_index()

cap_scatter_df = cap_scatter_df.sort_values(["Weight (g)"], ascending=True)
cap_grouped_weight = cap_scatter_df.groupby("Weight (g)")["Tumor Volume (mm3)"].mean()

cap_grouped_plot = pd.DataFrame(cap_grouped_weight).reset_index()
print(cap_grouped_weight)
cap_grouped_plot.plot(kind='scatter', x='Weight (g)', y='Tumor Volume (mm3)', grid = True, figsize= (8,8))
plt.title("Scatter plot of mouse weight versus average tumor volume for the drug, Capomulin")
# Out:
# Weight (g)
# 15    36.182040
# 17    37.214133
# 19    41.182391
# 20    39.141053
# 21    42.088700
# 22    43.288490
# 23    43.341051
# 24    44.805810
# 25    44.062109
# Name: Tumor Volume (mm3), dtype: float64
# Text(0.5, 1.0, 'Scatter plot of mouse weight versus average tumor volume for the drug, Capomulin')

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
x_values = cap_grouped_plot["Weight (g)"]
y_values = cap_grouped_plot["Tumor Volume (mm3)"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y =" + str(round(slope,2)) + "x + " + str(round(intercept,2))

CorrCoeff = cap_grouped_plot.corr()
CorrCoeff_Val = round(CorrCoeff['Weight (g)'][1],3)
print(f"The correlation coefficient is = {CorrCoeff_Val}")


plt.scatter(x_values, y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(20,40),fontsize=10,color="red")
plt.xlabel("Weight")
plt.ylabel("Tumor Volume")
plt.title("Weight Vs. Avg Tumor Vol")
plt.show()
# Out:
# The correlation coefficient is = 0.951

# %%
#Ttrying out queries for reference - not part of homwwork

a = pd.DataFrame(tumor_df.groupby(["Drug Regimen"])[["Mouse ID"]].count())
a
# Out:
#               Mouse ID
# Drug Regimen
# Capomulin           25
# Ceftamin            25
# Infubinol           25
# Ketapril            25
# Naftisol            25
# Placebo             25
# Propriva            24
# Ramicane            25
# Stelasyn            24
# Zoniferol           25

# %%
tumor_df
# Out:
#     Mouse ID  Timepoint Drug Regimen     Sex  Age_months  Weight (g)  \
# 0       a203         45    Infubinol  Female          20          23
# 1       a251         45    Infubinol  Female          21          25
# 2       a262         45      Placebo  Female          17          29
# 3       a275         45     Ceftamin  Female          20          28
# 4       a366         30     Stelasyn  Female          16          29
# ..       ...        ...          ...     ...         ...         ...
# 243     z435         10     Propriva  Female          12          26
# 244     z578         45     Ramicane    Male          11          16
# 245     z581         45    Infubinol  Female          24          25
# 246     z795         45     Naftisol  Female          13          29
# 247     z969         45     Naftisol    Male           9          30
#
#      Tumor Volume (mm3)  Metastatic Sites
# 0             67.973419                 2
# 1             65.525743                 1
# ...

# %%
tumor_df.loc[tumor_df["Drug Regimen"] == "Capomulin"]
# Out:
#     Mouse ID  Timepoint Drug Regimen     Sex  Age_months  Weight (g)  \
# 19      b128         45    Capomulin  Female           9          22
# 24      b742         45    Capomulin    Male           7          21
# 61      f966         20    Capomulin    Male          16          17
# 64      g288         45    Capomulin    Male           3          19
# 66      g316         45    Capomulin  Female          22          22
# 80      i557         45    Capomulin  Female           1          24
# 83      i738         45    Capomulin  Female          23          20
# 85      j119         45    Capomulin  Female           7          23
# 87      j246         35    Capomulin  Female          21          21
# 108     l509         45    Capomulin    Male          17          21
# 115     l897         45    Capomulin    Male          17          19
# 121     m601         45    Capomulin    Male          22          17
# 124     m957         45    Capomulin  Female           3          19
# ...

# %%
mouse_tumor_list = line_plot_df['Tumor Volume (mm3)'].tolist()
mouse_timepoint_list = line_plot_df['Timepoint'].tolist()
mouse_tumor_list
# Out:
# [45.0,
#  45.76088647,
#  46.56841719,
#  47.21219992,
#  40.34394812,
#  35.50361557,
#  35.9783344,
#  35.45948978,
#  36.02413752,
#  31.02392294]

# %%
mouse_timepoint_list
# Out:
# [0, 5, 10, 15, 20, 25, 30, 35, 40, 45]
